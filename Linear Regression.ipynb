# %% [markdown]
# ### __Utilisation de la librairie Panda__

# %%
# All imports
import pandas as pnd
from pandas import DataFrame

# %%
data = pnd.read_csv("cost_revenue_clean.csv")

# Display the spreadsheet that we imported
data
# Out:
#       production_budget_usd  worldwide_gross_usd
# 0                   1000000                   26
# 1                     10000                  401
# 2                    400000                  423
# 3                    750000                  450
# 4                     10000                  527
# ...                     ...                  ...
# 5029              225000000           1519479547
# 5030              215000000           1671640593
# 5031              306000000           2058662225
# 5032              200000000           2207615668
# 5033              425000000           2783918982
#
# [5034 rows x 2 columns]

# %%
# Display the spreandsheet's infos
data.describe()
# Out:
#        production_budget_usd  worldwide_gross_usd
# count           5.034000e+03         5.034000e+03
# mean            3.290784e+07         9.515685e+07
# std             4.112589e+07         1.726012e+08
# min             1.100000e+03         2.600000e+01
# 25%             6.000000e+06         7.000000e+06
# 50%             1.900000e+07         3.296202e+07
# 75%             4.200000e+07         1.034471e+08
# max             4.250000e+08         2.783919e+09

# %% [markdown]
# ## __Utilisation du module dataframe__

# %%
x = DataFrame(data, columns=["production_budget_usd"])
y = DataFrame(data, columns=["worldwide_gross_usd"])

# %% [markdown]
# ## __Utilisation de la librairie Matplotlib__

# %%
import matplotlib.pyplot as plt


plt.figure(figsize = (10,6))
plt.scatter(x,y, alpha=0.3)
plt.ylabel("Growth Revenue $")
plt.xlabel("Production costs $")
plt.title("Production Cost VS Growth Revenue")
plt.ylim(0, 3000000000)
plt.xlim(0, 450000000)
plt.show()

# %% [markdown]
# ## __Utilisation de la librairie SCIKIT__

# %%
from sklearn.linear_model import LinearRegression

regression = LinearRegression()

regression.fit(x,y)

regression.coef_
regression.intercept_
# Out:
# array([-7236192.72913958])

# %% [markdown]
# ## __Représentation du graphe avec la régression linéaire__

# %%
plt.figure(figsize = (10,6))
plt.scatter(x,y, alpha=0.3)

plt.plot(x,regression.predict(x), color = 'green', linewidth = 4)
plt.ylabel("Growth Revenue $")
plt.xlabel("Production costs $")
plt.title("Production Cost VS Growth Revenue")
plt.ylim(0, 3000000000)
plt.xlim(0, 450000000)
plt.show()

# %% [markdown]
# ## __Calcul du score obtenu par mon modèle__

# %%
regression.score(x, y)
# Out:
# 0.5496485356985729

# %%
regression.predict(x)
# Out:
# array([[-4.12468355e+06],
#        [-7.20507764e+06],
#        [-5.99158906e+06],
#        ...,
#        [ 9.44885617e+08],
#        [ 6.15065644e+08],
#        [ 1.31515521e+09]])
